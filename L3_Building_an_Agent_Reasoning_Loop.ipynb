# %% [markdown]
# # Building an Agent Reasoning Loop

# %%
from helper import get_openai_api_key
OPENAI_API_KEY = get_openai_api_key()

# %%
import nest_asyncio
nest_asyncio.apply()

# %% [markdown]
# # Load The Data

# %%
from utils import get_doc_tools

vector_tool, summary_tool = get_doc_tools("metagpt.pdf", "metagpt")
# Out:
# [nltk_data] Downloading package punkt_tab to
# [nltk_data]     /Users/anusingh/Documents/LAB3/.venv/lib/python3.9/sit
# [nltk_data]     e-packages/llama_index/core/_static/nltk_cache...
# [nltk_data]   Package punkt_tab is already up-to-date!

# %% [markdown]
# ## Setup functions calling agents

# %%
from llama_index.llms.openai import OpenAI

llm = OpenAI(model="gpt-3.5-turbo", temperature=0)

# %%
from utils import get_doc_tools

vector_tool, summary_tool = get_doc_tools("metagpt.pdf", "metagpt")

# %%
from llama_index.core.agent import FunctionCallingAgentWorker
from llama_index.core.agent import AgentRunner

agent_worker = FunctionCallingAgentWorker.from_tools(
    [vector_tool, summary_tool], 
    llm=llm, 
    verbose=True
)
agent = AgentRunner(agent_worker)

# %%
response = agent.query(
    "Tell me about the agent roles in MetaGPT, "
    "and then how they communicate with each other."
)
# Out:
# Added user message to memory: Tell me about the agent roles in MetaGPT, and then how they communicate with each other.
# === Calling Function ===
# Calling function: summary_tool_metagpt with args: {"input": "agent roles in MetaGPT"}
# /Users/anusingh/Documents/LAB3/.venv/lib/python3.9/site-packages/llama_index/core/tools/calling.py:26: RuntimeWarning: coroutine 'run_async_tasks.<locals>._gather' was never awaited
#   return ToolOutput(
# RuntimeWarning: Enable tracemalloc to get the object allocation traceback
# /Users/anusingh/Documents/LAB3/.venv/lib/python3.9/site-packages/llama_index/core/tools/calling.py:26: RuntimeWarning: coroutine 'Dispatcher.span.<locals>.async_wrapper' was never awaited
#   return ToolOutput(
# RuntimeWarning: Enable tracemalloc to get the object allocation traceback
# /Users/anusingh/opt/anaconda3/lib/python3.9/abc.py:123: RuntimeWarning: coroutine 'run_async_tasks.<locals>._gather' was never awaited
#   return _abc_subclasscheck(cls, subclass)
# RuntimeWarning: Enable tracemalloc to get the object allocation traceback
# /Users/anusingh/opt/anaconda3/lib/python3.9/abc.py:123: RuntimeWarning: coroutine 'Dispatcher.span.<locals>.async_wrapper' was never awaited
#   return _abc_subclasscheck(cls, subclass)
# RuntimeWarning: Enable tracemalloc to get the object allocation traceback
# === Function Output ===
# Encountered error: Detected nested async. Please use nest_asyncio.apply() to allow nested event loops.Or, use async entry methods like `aquery()`, `aretriever`, `achat`, etc.
# === Calling Function ===
# Calling function: vector_tool_metagpt with args: {"query": "agent roles in MetaGPT"}
# === Function Output ===
# In MetaGPT, the agent roles include Product Manager, Architect, Project Manager, Engineer, and QA Engineer. Each role has specific responsibilities and expertise tailored to different aspects of the software development process within the framework. The roles are designed to collaborate effectively, with each agent contributing specialized outputs to address specific tasks and problems.
# === Calling Function ===
# Calling function: summary_tool_metagpt with args: {"input": "how agents communicate with each other in MetaGPT"}
# === Function Output ===
# Encountered error: Detected nested async. Please use nest_asyncio.apply() to allow nested event loops.Or, use async entry methods like `aquery()`, `aretriever`, `achat`, etc.
# /Users/anusingh/opt/anaconda3/lib/python3.9/typing.py:294: RuntimeWarning: coroutine 'run_async_tasks.<locals>._gather' was never awaited
#   ev_args = tuple(_eval_type(a, globalns, localns, recursive_guard) for a in t.__args__)
# RuntimeWarning: Enable tracemalloc to get the object allocation traceback
# /Users/anusingh/opt/anaconda3/lib/python3.9/typing.py:294: RuntimeWarning: coroutine 'Dispatcher.span.<locals>.async_wrapper' was never awaited
#   ev_args = tuple(_eval_type(a, globalns, localns, recursive_guard) for a in t.__args__)
# RuntimeWarning: Enable tracemalloc to get the object allocation traceback
# === Calling Function ===
# Calling function: vector_tool_metagpt with args: {"query": "how agents communicate with each other in MetaGPT"}
# === Function Output ===
# Agents in MetaGPT communicate with each other by utilizing a shared message pool where they publish structured messages and subscribe to relevant messages based on their profiles. This communication protocol enhances role communication efficiency by allowing agents to exchange messages directly, access messages from other entities transparently, and retrieve required information from the shared pool without the need to inquire about other agents. Additionally, agents in MetaGPT communicate through documents and diagrams (structured outputs) rather than dialogue, ensuring that all necessary information is provided and preventing irrelevant or missing content.
# === LLM Response ===
# In MetaGPT, the agent roles include Product Manager, Architect, Project Manager, Engineer, and QA Engineer. These roles have specific responsibilities and expertise tailored to different aspects of the software development process within the framework. The roles are designed to collaborate effectively, with each agent contributing specialized outputs to address specific tasks and problems.
#
# Agents in MetaGPT communicate with each other by utilizing a shared message pool where they publish structured messages and subscribe to relevant messages based on their profiles. This communication protocol enhances role communication efficiency by allowing agents to exchange messages directly, access messages from other entities transparently, and retrieve required information from the shared pool without the need to inquire about other agents. Additionally, agents communicate through documents and diagrams (structured outputs) rather than dialogue, ensuring all necessary information is provided and preventing irrelevant or missing content.

# %%
if response.source_nodes:
    print(response.source_nodes[0].get_content(metadata_mode="all"))
else:
    print("No source nodes found")
# Out:
# No source nodes found

# %%
response = agent.chat(
    "Tell me about the evaluation datasets used."
)
# Out:
# Added user message to memory: Tell me about the evaluation datasets used.
# === Calling Function ===
# Calling function: summary_tool_metagpt with args: {"input": "evaluation datasets used in MetaGPT"}
# === Function Output ===
# Encountered error: Detected nested async. Please use nest_asyncio.apply() to allow nested event loops.Or, use async entry methods like `aquery()`, `aretriever`, `achat`, etc.
# === Calling Function ===
# Calling function: vector_tool_metagpt with args: {"query": "evaluation datasets used in MetaGPT"}
# === Function Output ===
# The evaluation datasets used in MetaGPT include the SoftwareDev dataset, which consists of 70 diverse software development tasks. Within this dataset, 11 tasks are detailed, with the first seven tasks being utilized in the main experiments discussed in the provided context.
# === LLM Response ===
# The evaluation datasets used in MetaGPT include the SoftwareDev dataset, which consists of 70 diverse software development tasks. Within this dataset, 11 tasks are detailed, with the first seven tasks being utilized in the main experiments discussed in the provided context.

# %%
response = agent.chat("Tell me the results over one of the above datasets.")
# Out:
# Added user message to memory: Tell me the results over one of the above datasets.
# === Calling Function ===
# Calling function: summary_tool_metagpt with args: {"input": "results over the SoftwareDev dataset in MetaGPT"}
# === Function Output ===
# Encountered error: Detected nested async. Please use nest_asyncio.apply() to allow nested event loops.Or, use async entry methods like `aquery()`, `aretriever`, `achat`, etc.
# === Calling Function ===
# Calling function: vector_tool_metagpt with args: {"query": "results over the SoftwareDev dataset in MetaGPT"}
# /Users/anusingh/Documents/LAB3/.venv/lib/python3.9/site-packages/tenacity/__init__.py:238: RuntimeWarning: coroutine 'run_async_tasks.<locals>._gather' was never awaited
#   self._local = threading.local()
# RuntimeWarning: Enable tracemalloc to get the object allocation traceback
# /Users/anusingh/Documents/LAB3/.venv/lib/python3.9/site-packages/tenacity/__init__.py:238: RuntimeWarning: coroutine 'Dispatcher.span.<locals>.async_wrapper' was never awaited
#   self._local = threading.local()
# RuntimeWarning: Enable tracemalloc to get the object allocation traceback
# === Function Output ===
# MetaGPT achieves an average score of 3.9 over the SoftwareDev dataset, surpassing ChatDev's score of 2.1. It simplifies the process of transforming abstract requirements into detailed class and function designs through a specialized division of labor and SOPs workflow. Additionally, MetaGPT's structured messaging and feedback mechanisms reduce loss of communication information and improve the execution of code.
# === LLM Response ===
# MetaGPT achieves an average score of 3.9 over the SoftwareDev dataset, surpassing ChatDev's score of 2.1. It simplifies the process of transforming abstract requirements into detailed class and function designs through a specialized division of labor and SOPs workflow. Additionally, MetaGPT's structured messaging and feedback mechanisms reduce loss of communication information and improve the execution of code.

# %% [markdown]
# ## Lower level: Debuggability and Control

# %%
agent_worker = FunctionCallingAgentWorker.from_tools(
    [vector_tool, summary_tool], 
    llm=llm, 
    verbose=True
)
agent = AgentRunner(agent_worker)

# %%
task = agent.create_task(
    "Tell me about the agent roles in MetaGPT, "
    "and then how they communicate with each other."
)

# %%
step_output = agent.run_step(task.task_id)
# Out:
# Added user message to memory: Tell me about the agent roles in MetaGPT, and then how they communicate with each other.
# === Calling Function ===
# Calling function: summary_tool_metagpt with args: {"input": "agent roles in MetaGPT"}
# === Function Output ===
# Encountered error: Detected nested async. Please use nest_asyncio.apply() to allow nested event loops.Or, use async entry methods like `aquery()`, `aretriever`, `achat`, etc.

# %%
completed_steps = agent.get_completed_steps(task.task_id)
print(f"Num completed for task {task.task_id}: {len(completed_steps)}")
print(completed_steps[0].output.sources[0].raw_output)
# Out:
# Num completed for task 68037368-8112-4e8f-84b5-dc9829df0e9b: 1
# Detected nested async. Please use nest_asyncio.apply() to allow nested event loops.Or, use async entry methods like `aquery()`, `aretriever`, `achat`, etc.

# %%
upcoming_steps = agent.get_upcoming_steps(task.task_id)
print(f"Num upcoming steps for task {task.task_id}: {len(upcoming_steps)}")
upcoming_steps[0]
# Out:
# Num upcoming steps for task 68037368-8112-4e8f-84b5-dc9829df0e9b: 1
# /Users/anusingh/opt/anaconda3/lib/python3.9/inspect.py:2926: RuntimeWarning: coroutine 'run_async_tasks.<locals>._gather' was never awaited
#   param = next(parameters)
# RuntimeWarning: Enable tracemalloc to get the object allocation traceback
# /Users/anusingh/opt/anaconda3/lib/python3.9/inspect.py:2926: RuntimeWarning: coroutine 'Dispatcher.span.<locals>.async_wrapper' was never awaited
#   param = next(parameters)
# RuntimeWarning: Enable tracemalloc to get the object allocation traceback
# TaskStep(task_id='68037368-8112-4e8f-84b5-dc9829df0e9b', step_id='f6f10590-1d6e-4f28-a2a3-ef11b9f55ff2', input=None, step_state={}, next_steps={}, prev_steps={}, is_ready=True)

# %%
step_output = agent.run_step(
    task.task_id, input="What about how agents share information?"
)
# Out:
# Added user message to memory: What about how agents share information?
# === Calling Function ===
# Calling function: summary_tool_metagpt with args: {"input": "how agents share information in MetaGPT"}
# === Function Output ===
# Encountered error: Detected nested async. Please use nest_asyncio.apply() to allow nested event loops.Or, use async entry methods like `aquery()`, `aretriever`, `achat`, etc.

# %%
step_output = agent.run_step(task.task_id)
print(step_output.is_last)
# Out:
# === LLM Response ===
# It seems there was an error in retrieving the information about how agents share information in MetaGPT. Let me try to gather the information using a different approach.
# === Calling Function ===
# Calling function: vector_tool_metagpt with args: {"query": "how agents share information in MetaGPT"}
# === Function Output ===
# Agents in MetaGPT share information by using a shared message pool to publish structured messages. They can also subscribe to relevant messages based on their profiles. This allows agents to obtain directional information from other roles and public information from the environment, facilitating efficient communication and collaboration within the framework.
# False

# %%
while True:
    step_output = agent.run_step(task.task_id)
    print("Is last step:", step_output.is_last)

    if step_output.is_last:
        break
# Out:
# === LLM Response ===
# Agents in MetaGPT share information by using a shared message pool to publish structured messages. They can also subscribe to relevant messages based on their profiles. This allows agents to obtain directional information from other roles and public information from the environment, facilitating efficient communication and collaboration within the framework.
# Is last step: True

# %%
print(str(response))
# Out:
# MetaGPT achieves an average score of 3.9 over the SoftwareDev dataset, surpassing ChatDev's score of 2.1. It simplifies the process of transforming abstract requirements into detailed class and function designs through a specialized division of labor and SOPs workflow. Additionally, MetaGPT's structured messaging and feedback mechanisms reduce loss of communication information and improve the execution of code.
